# %%
# Database dependencies
import pandas as pd
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from config import password
import numpy as np

# %%
# Database credentials
DATABASES = {
    'finalproject':{
        'POSTGRES_ADDRESS' :'finalproject.c969jxlkzz2v.us-east-2.rds.amazonaws.com',
        'POSTGRES_PORT' : '5432',
        'POSTGRES_USERNAME' : "postgres",
        'POSTGRES_PASSWORD' : password,
        'POSTGRES_DBNAME' : 'housingdata',
    },
}
# Choose the database to use
db = DATABASES['finalproject']
# Connect to postgres
postgres_str = ('postgresql+psycopg2://{username}:{password}@{ipaddress}:{port}/{dbname}'
               .format(username= db['POSTGRES_USERNAME'],
                      password= db['POSTGRES_PASSWORD'],
                      ipaddress= db['POSTGRES_ADDRESS'],
                      port= db['POSTGRES_PORT'],
                      dbname= db['POSTGRES_DBNAME'])
               )
# Create an database engine instance
connection = create_engine(postgres_str)

# %%
Base = automap_base()
Base.prepare(connection,reflect = True)
Base.classes.keys()
# Out:
# ['income_data',
#  'acs_data',
#  'city_data',
#  'demo_by_city',
#  'final_table',
#  'zhvi_data']

# %%
final_table = Base.classes.final_table
session = Session(connection)

# %%
def fixer(x):
    try:
        y=int(x)
    except:
        y=None
    return y

# %%
result = session.query(final_table.city, final_table.race_w, final_table.race_aa, final_table.eth_hisp, final_table.median_income, final_table.vio_crime, final_table.prop_crime, final_table.lat, final_table.long).all()
df = pd.DataFrame(result).fillna(value=0)#.to_dict("record")
df["race_w"] = df["race_w"].map(lambda x:int(x))
df["race_aa"] = df["race_aa"].map(lambda x:int(x))
df["eth_hisp"] = df["eth_hisp"].map(lambda x:int(x))
df["median_income"] = df["median_income"].map(fixer)
df["vio_crime"] = df["vio_crime"].map(lambda x:int(x))
df["prop_crime"] = df["prop_crime"].map(lambda x:int(x))
df["lat"] = df["lat"].map(lambda x:float(x))
df["long"] = df["long"].map(lambda x:float(x))
df.to_dict("record")
# Out:
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:1490: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   FutureWarning,
# [{'city': 'Shabbona',
#   'race_w': 1446,
#   'race_aa': 4,
#   'eth_hisp': 24,
#   'median_income': 58125.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.7680851,
#   'long': -88.8770311},
#  {'city': 'New Baden',
#   'race_w': 4185,
#   'race_aa': 219,
#   'eth_hisp': 103,
#   'median_income': nan,
#   'vio_crime': 7,
#   'prop_crime': 36,
#   'lat': 38.5350488,
#   'long': -89.7006499},
#  {'city': 'Ellis Grove',
#   'race_w': 971,
#   'race_aa': 1,
#   'eth_hisp': 19,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.0089404,
#   'long': -89.9059408},
#  {'city': 'Bunker Hill',
#   'race_w': 4056,
#   'race_aa': 35,
#   'eth_hisp': 58,
#   'median_income': nan,
#   'vio_crime': 1,
#   'prop_crime': 22,
#   'lat': 39.0428239,
#   'long': -89.951769},
#  {'city': 'Martinton',
#   'race_w': 808,
#   'race_aa': 8,
#   'eth_hisp': 29,
#   'median_income': 70179.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.9158671,
#   'long': -87.7253124},
#  {'city': 'Altona',
#   'race_w': 902,
#   'race_aa': 32,
#   'eth_hisp': 16,
#   'median_income': 54965.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.1147594,
#   'long': -90.1645637},
#  {'city': 'Aurora',
#   'race_w': 126135,
#   'race_aa': 25448,
#   'eth_hisp': 92657,
#   'median_income': 83248.0,
#   'vio_crime': 538,
#   'prop_crime': 2301,
#   'lat': 41.7605849,
#   'long': -88.3200715},
#  {'city': 'Wilmington',
#   'race_w': 10974,
#   'race_aa': 120,
#   'eth_hisp': 736,
#   'median_income': 61090.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.3078094,
#   'long': -88.1467243},
#  {'city': 'Wilmington',
#   'race_w': 10974,
#   'race_aa': 120,
#   'eth_hisp': 736,
#   'median_income': 61090.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.3078094,
#   'long': -88.1467243},
#  {'city': 'Wilmington',
#   'race_w': 10974,
#   'race_aa': 120,
#   'eth_hisp': 736,
#   'median_income': 61090.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.4806831,
#   'long': -90.4867659},
#  {'city': 'Wilmington',
#   'race_w': 10974,
#   'race_aa': 120,
#   'eth_hisp': 736,
#   'median_income': 61090.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.4806831,
#   'long': -90.4867659},
#  {'city': 'Monroe Center',
#   'race_w': 817,
#   'race_aa': 4,
#   'eth_hisp': 38,
#   'median_income': 60000.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.0983583,
#   'long': -89.000655},
#  {'city': 'Staunton',
#   'race_w': 6563,
#   'race_aa': 5,
#   'eth_hisp': 13,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.0122684,
#   'long': -89.7912063},
#  {'city': 'Chester',
#   'race_w': 7112,
#   'race_aa': 2510,
#   'eth_hisp': 562,
#   'median_income': nan,
#   'vio_crime': 16,
#   'prop_crime': 14,
#   'lat': 37.9136628,
#   'long': -89.8220505},
#  {'city': 'Colona',
#   'race_w': 6798,
#   'race_aa': 304,
#   'eth_hisp': 829,
#   'median_income': 64552.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.4839233,
#   'long': -90.3531827},
#  {'city': 'Patoka',
#   'race_w': 1221,
#   'race_aa': 20,
#   'eth_hisp': 29,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.7553259,
#   'long': -89.0953417},
#  {'city': 'Dwight',
#   'race_w': 4736,
#   'race_aa': 92,
#   'eth_hisp': 124,
#   'median_income': 62669.0,
#   'vio_crime': 5,
#   'prop_crime': 38,
#   'lat': 41.0944767,
#   'long': -88.4250597},
#  {'city': 'Port Byron',
#   'race_w': 4561,
#   'race_aa': 66,
#   'eth_hisp': 278,
#   'median_income': 68774.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.6064219,
#   'long': -90.3354061},
#  {'city': 'Pesotum',
#   'race_w': 781,
#   'race_aa': 1,
#   'eth_hisp': 93,
#   'median_income': 69750.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.9147532,
#   'long': -88.2733827},
#  {'city': 'Schiller Park',
#   'race_w': 9788,
#   'race_aa': 156,
#   'eth_hisp': 2894,
#   'median_income': 54617.0,
#   'vio_crime': 17,
#   'prop_crime': 219,
#   'lat': 41.9558637,
#   'long': -87.8708965},
#  {'city': 'Kempton',
#   'race_w': 439,
#   'race_aa': 0,
#   'eth_hisp': 1,
#   'median_income': 55714.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.9355888,
#   'long': -88.237273},
#  {'city': 'Orangeville',
#   'race_w': 1418,
#   'race_aa': 0,
#   'eth_hisp': 9,
#   'median_income': 50893.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.4683453,
#   'long': -89.6440073},
#  {'city': 'Gardner',
#   'race_w': 2412,
#   'race_aa': 6,
#   'eth_hisp': 150,
#   'median_income': 62237.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.1855879,
#   'long': -88.3097828},
#  {'city': 'Park Forest',
#   'race_w': 6654,
#   'race_aa': 14967,
#   'eth_hisp': 1153,
#   'median_income': 51324.0,
#   'vio_crime': 61,
#   'prop_crime': 344,
#   'lat': 41.4914236,
#   'long': -87.6744891},
#  {'city': 'Jewett',
#   'race_w': 697,
#   'race_aa': 15,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.2078171,
#   'long': -88.2458744},
#  {'city': 'Maple Park',
#   'race_w': 3933,
#   'race_aa': 81,
#   'eth_hisp': 131,
#   'median_income': 89205.0,
#   'vio_crime': 1,
#   'prop_crime': 8,
#   'lat': 41.9075282,
#   'long': -88.5992494},
#  {'city': 'Oak Brook',
#   'race_w': 7043,
#   'race_aa': 340,
#   'eth_hisp': 364,
#   'median_income': 103464.0,
#   'vio_crime': 10,
#   'prop_crime': 552,
#   'lat': 41.8328085,
#   'long': -87.9289504},
#  {'city': 'Irvington',
#   'race_w': 691,
#   'race_aa': 7,
#   'eth_hisp': 4,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.4392162,
#   'long': -89.1628512},
#  {'city': 'Camargo',
#   'race_w': 942,
#   'race_aa': 0,
#   'eth_hisp': 4,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.8003105,
#   'long': -88.1639315},
#  {'city': 'Gifford',
#   'race_w': 1216,
#   'race_aa': 21,
#   'eth_hisp': 25,
#   'median_income': 74792.0,
#   'vio_crime': 0,
#   'prop_crime': 3,
#   'lat': 40.305868,
#   'long': -88.0211489},
#  {'city': 'Atwood',
#   'race_w': 1454,
#   'race_aa': 1,
#   'eth_hisp': 7,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.7994772,
#   'long': -88.4622789},
#  {'city': 'Matherville',
#   'race_w': 730,
#   'race_aa': 0,
#   'eth_hisp': 81,
#   'median_income': 59750.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.2597571,
#   'long': -90.6079133},
#  {'city': 'Elburn',
#   'race_w': 9623,
#   'race_aa': 357,
#   'eth_hisp': 1193,
#   'median_income': 104516.0,
#   'vio_crime': 0,
#   'prop_crime': 13,
#   'lat': 41.8922499,
#   'long': -88.4723014},
#  {'city': 'Grafton',
#   'race_w': 2156,
#   'race_aa': 61,
#   'eth_hisp': 18,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 22,
#   'lat': 38.9700484,
#   'long': -90.4315046},
#  {'city': 'Shorewood',
#   'race_w': 16550,
#   'race_aa': 1081,
#   'eth_hisp': 2277,
#   'median_income': 101911.0,
#   'vio_crime': 14,
#   'prop_crime': 101,
#   'lat': 41.5200305,
#   'long': -88.2017293},
#  {'city': 'Danvers',
#   'race_w': 2035,
#   'race_aa': 35,
#   'eth_hisp': 10,
#   'median_income': 83750.0,
#   'vio_crime': 0,
#   'prop_crime': 2,
#   'lat': 40.5294818,
#   'long': -89.1773055},
#  {'city': 'Minonk',
#   'race_w': 2472,
#   'race_aa': 34,
#   'eth_hisp': 39,
#   'median_income': 65208.0,
#   'vio_crime': 0,
#   'prop_crime': 20,
#   'lat': 40.9044778,
#   'long': -89.0345224},
#  {'city': 'Melrose Park',
#   'race_w': 31794,
#   'race_aa': 2303,
#   'eth_hisp': 32215,
#   'median_income': 55381.0,
#   'vio_crime': 85,
#   'prop_crime': 316,
#   'lat': 41.9005865,
#   'long': -87.8567277},
#  {'city': 'Savanna',
#   'race_w': 3973,
#   'race_aa': 159,
#   'eth_hisp': 205,
#   'median_income': 42969.0,
#   'vio_crime': 14,
#   'prop_crime': 98,
#   'lat': 42.0944672,
#   'long': -90.1567944},
#  {'city': 'Lena',
#   'race_w': 3840,
#   'race_aa': 26,
#   'eth_hisp': 73,
#   'median_income': 53455.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.3794586,
#   'long': -89.8223426},
#  {'city': 'Crete',
#   'race_w': 10203,
#   'race_aa': 4551,
#   'eth_hisp': 1101,
#   'median_income': 69491.0,
#   'vio_crime': 17,
#   'prop_crime': 132,
#   'lat': 41.4444791,
#   'long': -87.6314312},
#  {'city': 'Mattoon',
#   'race_w': 21317,
#   'race_aa': 547,
#   'eth_hisp': 384,
#   'median_income': nan,
#   'vio_crime': 99,
#   'prop_crime': 281,
#   'lat': 39.4830897,
#   'long': -88.3728255},
#  {'city': 'Berkeley',
#   'race_w': 2787,
#   'race_aa': 1491,
#   'eth_hisp': 1906,
#   'median_income': 64934.0,
#   'vio_crime': 5,
#   'prop_crime': 49,
#   'lat': 41.8889194,
#   'long': -87.9033956},
#  {'city': 'Stonington',
#   'race_w': 1030,
#   'race_aa': 0,
#   'eth_hisp': 15,
#   'median_income': nan,
#   'vio_crime': 1,
#   'prop_crime': 0,
#   'lat': 39.6400426,
#   'long': -89.1928608},
#  {'city': 'Heyworth',
#   'race_w': 4555,
#   'race_aa': 66,
#   'eth_hisp': 103,
#   'median_income': 78565.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.3133698,
#   'long': -88.9736901},
#  {'city': 'Bushnell',
#   'race_w': 3101,
#   'race_aa': 31,
#   'eth_hisp': 0,
#   'median_income': 44981.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.5528183,
#   'long': -90.50624},
#  {'city': 'New Lenox',
#   'race_w': 34238,
#   'race_aa': 340,
#   'eth_hisp': 2296,
#   'median_income': 108154.0,
#   'vio_crime': 35,
#   'prop_crime': 299,
#   'lat': 41.5119761,
#   'long': -87.9656098},
#  {'city': 'Illiopolis',
#   'race_w': 1297,
#   'race_aa': 0,
#   'eth_hisp': 30,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.8536535,
#   'long': -89.2420291},
#  {'city': 'Strasburg',
#   'race_w': 964,
#   'race_aa': 0,
#   'eth_hisp': 2,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.3525383,
#   'long': -88.619224},
#  {'city': 'Weldon',
#   'race_w': 693,
#   'race_aa': 0,
#   'eth_hisp': 4,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.1211468,
#   'long': -88.7453497},
#  {'city': 'Bethalto',
#   'race_w': 11051,
#   'race_aa': 177,
#   'eth_hisp': 162,
#   'median_income': nan,
#   'vio_crime': 5,
#   'prop_crime': 81,
#   'lat': 38.9092138,
#   'long': -90.0406608},
#  {'city': 'Edwardsville',
#   'race_w': 30610,
#   'race_aa': 3432,
#   'eth_hisp': 1055,
#   'median_income': nan,
#   'vio_crime': 13,
#   'prop_crime': 185,
#   'lat': 38.8114364,
#   'long': -89.953157},
#  {'city': 'Peoria',
#   'race_w': 93397,
#   'race_aa': 36337,
#   'eth_hisp': 7143,
#   'median_income': 30465.0,
#   'vio_crime': 860,
#   'prop_crime': 4509,
#   'lat': 40.6936488,
#   'long': -89.5889864},
#  {'city': 'Buffalo Grove',
#   'race_w': 30252,
#   'race_aa': 1130,
#   'eth_hisp': 2260,
#   'median_income': 111548.0,
#   'vio_crime': 7,
#   'prop_crime': 268,
#   'lat': 42.1514146,
#   'long': -87.959794},
#  {'city': 'Wilsonville',
#   'race_w': 460,
#   'race_aa': 3,
#   'eth_hisp': 15,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.0708798,
#   'long': -89.8562091},
#  {'city': 'Saint Peter',
#   'race_w': 690,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.8681017,
#   'long': -88.8539455},
#  {'city': 'Edgewood',
#   'race_w': 860,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.9206006,
#   'long': -88.6614402},
#  {'city': 'Makanda',
#   'race_w': 1971,
#   'race_aa': 99,
#   'eth_hisp': 49,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.6175502,
#   'long': -89.2089717},
#  {'city': 'Fairmount',
#   'race_w': 1337,
#   'race_aa': 3,
#   'eth_hisp': 14,
#   'median_income': 63417.0,
#   'vio_crime': 0,
#   'prop_crime': 3,
#   'lat': 40.0455911,
#   'long': -87.8305838},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 41.9166949,
#   'long': -88.1975725},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 41.9166949,
#   'long': -88.1975725},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 41.9166949,
#   'long': -88.1975725},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 42.22919,
#   'long': -88.355086},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 42.22919,
#   'long': -88.355086},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 42.22919,
#   'long': -88.355086},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 39.325041,
#   'long': -88.8995161},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 39.325041,
#   'long': -88.8995161},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 39.325041,
#   'long': -88.8995161},
#  {'city': 'Sibley',
#   'race_w': 413,
#   'race_aa': 3,
#   'eth_hisp': 3,
#   'median_income': 46250.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.5869788,
#   'long': -88.3811648},
#  {'city': 'Chadwick',
#   'race_w': 1286,
#   'race_aa': 10,
#   'eth_hisp': 28,
#   'median_income': 55481.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.0133599,
#   'long': -89.8906765},
#  {'city': 'Oakwood',
#   'race_w': 2940,
#   'race_aa': 18,
#   'eth_hisp': 88,
#   'median_income': 60068.0,
#   'vio_crime': 1,
#   'prop_crime': 13,
#   'lat': 40.1161471,
#   'long': -87.7783592},
#  {'city': 'Belle Rive',
#   'race_w': 832,
#   'race_aa': 0,
#   'eth_hisp': 2,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.2328265,
#   'long': -88.740615},
#  {'city': 'Kinderhook',
#   'race_w': 389,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.7022686,
#   'long': -91.1531957},
#  {'city': 'Pekin',
#   'race_w': 40945,
#   'race_aa': 975,
#   'eth_hisp': 879,
#   'median_income': 53504.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.5675388,
#   'long': -89.640658},
#  {'city': 'Macomb',
#   'race_w': 18433,
#   'race_aa': 1761,
#   'eth_hisp': 754,
#   'median_income': 42013.0,
#   'vio_crime': 56,
#   'prop_crime': 228,
#   'lat': 40.4592076,
#   'long': -90.6717971},
#  {'city': 'London Mills',
#   'race_w': 590,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': 51875.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.7105947,
#   'long': -90.2662355},
#  {'city': 'Bradford',
#   'race_w': 1274,
#   'race_aa': 24,
#   'eth_hisp': 25,
#   'median_income': 55417.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.1772594,
#   'long': -89.6575977},
#  {'city': 'Ava',
#   'race_w': 1820,
#   'race_aa': 0,
#   'eth_hisp': 23,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.8883846,
#   'long': -89.4948169},
#  {'city': 'Rockford',
#   'race_w': 135806,
#   'race_aa': 38480,
#   'eth_hisp': 30338,
#   'median_income': 44305.0,
#   'vio_crime': 2027,
#   'prop_crime': 5368,
#   'lat': 42.2711311,
#   'long': -89.0939952},
#  {'city': 'Harvard',
#   'race_w': 12903,
#   'race_aa': 174,
#   'eth_hisp': 5605,
#   'median_income': 58264.0,
#   'vio_crime': 8,
#   'prop_crime': 64,
#   'lat': 42.422241,
#   'long': -88.6137101},
#  {'city': 'Calumet City',
#   'race_w': 8642,
#   'race_aa': 27669,
#   'eth_hisp': 5596,
#   'median_income': 42718.0,
#   'vio_crime': 187,
#   'prop_crime': 980,
#   'lat': 41.6155909,
#   'long': -87.5294871},
#  {'city': 'Bolingbrook',
#   'race_w': 39180,
#   'race_aa': 16395,
#   'eth_hisp': 18943,
#   'median_income': 97642.0,
#   'vio_crime': 112,
#   'prop_crime': 592,
#   'lat': 41.6986416,
#   'long': -88.0683955},
#  {'city': 'Percy',
#   'race_w': 1590,
#   'race_aa': 27,
#   'eth_hisp': 193,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.0164398,
#   'long': -89.6187089},
#  {'city': 'Wheaton',
#   'race_w': 53232,
#   'race_aa': 3034,
#   'eth_hisp': 3466,
#   'median_income': 101130.0,
#   'vio_crime': 39,
#   'prop_crime': 629,
#   'lat': 41.8661403,
#   'long': -88.1070127},
#  {'city': 'Emington',
#   'race_w': 245,
#   'race_aa': 14,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.9697547,
#   'long': -88.3581096},
#  {'city': 'Tremont',
#   'race_w': 4121,
#   'race_aa': 10,
#   'eth_hisp': 58,
#   'median_income': 80220.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.5275392,
#   'long': -89.4925979},
#  {'city': 'Lincolnshire',
#   'race_w': 7216,
#   'race_aa': 95,
#   'eth_hisp': 237,
#   'median_income': 102632.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.1900249,
#   'long': -87.9084039},
#  {'city': 'Union Hill',
#   'race_w': 58,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': 62188.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.1075321,
#   'long': -88.1467188},
#  {'city': 'Saint David',
#   'race_w': 519,
#   'race_aa': 0,
#   'eth_hisp': 1,
#   'median_income': 43250.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.4933728,
#   'long': -90.0487284},
#  {'city': 'Pearl',
#   'race_w': 520,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.4597701,
#   'long': -90.6259588},
#  {'city': 'Stonefort',
#   'race_w': 1401,
#   'race_aa': 81,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.6142165,
#   'long': -88.7081133},
#  {'city': 'Joy',
#   'race_w': 1053,
#   'race_aa': 0,
#   'eth_hisp': 18,
#   'median_income': 45750.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.1967002,
#   'long': -90.8804201},
#  {'city': 'Forreston',
#   'race_w': 2231,
#   'race_aa': 66,
#   'eth_hisp': 101,
#   'median_income': 53906.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.1261367,
#   'long': -89.5792801},
#  {'city': 'Marine',
#   'race_w': 1648,
#   'race_aa': 0,
#   'eth_hisp': 41,
#   'median_income': nan,
#   'vio_crime': 1,
#   'prop_crime': 2,
#   'lat': 38.7864361,
#   'long': -89.7775939},
#  {'city': 'East Carondelet',
#   'race_w': 1678,
#   'race_aa': 51,
#   'eth_hisp': 212,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.5419967,
#   'long': -90.2328909},
#  {'city': 'Sheffield',
#   'race_w': 1103,
#   'race_aa': 23,
#   'eth_hisp': 47,
#   'median_income': 52813.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.3583693,
#   'long': -89.7373226},
#  {'city': 'Palos Hills',
#   'race_w': 16101,
#   'race_aa': 978,
#   'eth_hisp': 1515,
#   'median_income': 59104.0,
#   'vio_crime': 18,
#   'prop_crime': 84,
#   'lat': 41.6966992,
#   'long': -87.8169984},
#  {'city': 'Johnston City',
#   'race_w': 4480,
#   'race_aa': 2,
#   'eth_hisp': 70,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.8206053,
#   'long': -88.9275695},
#  {'city': 'La Salle',
#   'race_w': 9410,
#   'race_aa': 159,
#   'eth_hisp': 1887,
#   'median_income': 47692.0,
#   'vio_crime': 0,
#   'prop_crime': 103,
#   'lat': 41.3333679,
#   'long': -89.0917497},
#  {'city': 'Sherman',
#   'race_w': 5861,
#   'race_aa': 41,
#   'eth_hisp': 186,
#   'median_income': nan,
#   'vio_crime': 3,
#   'prop_crime': 21,
#   'lat': 39.8936608,
#   'long': -89.6048231},
#  {'city': 'Albion',
#   'race_w': 3262,
#   'race_aa': 45,
#   'eth_hisp': 67,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.3775484,
#   'long': -88.0561465},
#  {'city': 'Westfield',
#   'race_w': 960,
#   'race_aa': 3,
#   'eth_hisp': 11,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.4564247,
#   'long': -87.996146},
#  {'city': 'Hopedale',
#   'race_w': 1475,
#   'race_aa': 7,
#   'eth_hisp': 17,
#   'median_income': 77578.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.4208735,
#   'long': -89.4145404},
#  {'city': 'Herod',
#   'race_w': 446,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.5803268,
#   'long': -88.4361547},
#  {'city': 'Maywood',
#   'race_w': 4044,
#   'race_aa': 16391,
#   'eth_hisp': 6510,
#   'median_income': 48600.0,
#   'vio_crime': 135,
#   'prop_crime': 570,
#   'lat': 41.8791979,
#   'long': -87.8431155},
#  {'city': 'Peotone',
#   'race_w': 5878,
#   'race_aa': 68,
#   'eth_hisp': 429,
#   'median_income': 83414.0,
#   'vio_crime': 3,
#   'prop_crime': 23,
#   'lat': 41.3322554,
#   'long': -87.7853217},
#  {'city': 'Murrayville',
#   'race_w': 1231,
#   'race_aa': 0,
#   'eth_hisp': 3,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.5856024,
#   'long': -90.2520645},
#  {'city': 'Palos Park',
#   'race_w': 9069,
#   'race_aa': 196,
#   'eth_hisp': 769,
#   'median_income': 87621.0,
#   'vio_crime': 0,
#   'prop_crime': 63,
#   'lat': 41.6672547,
#   'long': -87.8303316},
#  {'city': 'Greenup',
#   'race_w': 2781,
#   'race_aa': 2,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 2,
#   'prop_crime': 29,
#   'lat': 39.2478159,
#   'long': -88.1633719},
#  {'city': 'Davis',
#   'race_w': 3205,
#   'race_aa': 27,
#   'eth_hisp': 5,
#   'median_income': 67443.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.4225149,
#   'long': -89.4137259},
#  {'city': 'Quincy',
#   'race_w': 47917,
#   'race_aa': 3253,
#   'eth_hisp': 913,
#   'median_income': nan,
#   'vio_crime': 252,
#   'prop_crime': 1288,
#   'lat': 39.9356016,
#   'long': -91.4098727},
#  {'city': 'Cisco',
#   'race_w': 336,
#   'race_aa': 3,
#   'eth_hisp': 0,
#   'median_income': 59091.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.0114248,
#   'long': -88.7261827},
#  {'city': 'Rock City',
#   'race_w': 1479,
#   'race_aa': 2,
#   'eth_hisp': 0,
#   'median_income': 61364.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.4133485,
#   'long': -89.468171},
#  {'city': 'Pomona',
#   'race_w': 325,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.6281057,
#   'long': -89.3367556},
#  {'city': 'Lindenwood',
#   'race_w': 548,
#   'race_aa': 18,
#   'eth_hisp': 12,
#   'median_income': 59231.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.0530821,
#   'long': -89.0306545},
#  {'city': 'Belvidere',
#   'race_w': 29978,
#   'race_aa': 1034,
#   'eth_hisp': 9254,
#   'median_income': 58709.0,
#   'vio_crime': 60,
#   'prop_crime': 270,
#   'lat': 42.2639098,
#   'long': -88.8442674},
#  {'city': 'North Aurora',
#   'race_w': 14704,
#   'race_aa': 1001,
#   'eth_hisp': 2848,
#   'median_income': 81947.0,
#   'vio_crime': 24,
#   'prop_crime': 240,
#   'lat': 41.8061399,
#   'long': -88.3272952},
#  {'city': 'Farmington',
#   'race_w': 3274,
#   'race_aa': 0,
#   'eth_hisp': 77,
#   'median_income': 56528.0,
#   'vio_crime': 6,
#   'prop_crime': 27,
#   'lat': 40.6980933,
#   'long': -90.0059483},
#  {'city': 'Warrenville',
#   'race_w': 11813,
#   'race_aa': 726,
#   'eth_hisp': 2537,
#   'median_income': 82106.0,
#   'vio_crime': 13,
#   'prop_crime': 108,
#   'lat': 41.817807,
#   'long': -88.1734021},
#  {'city': 'Chatham',
#   'race_w': 13330,
#   'race_aa': 219,
#   'eth_hisp': 259,
#   'median_income': nan,
#   'vio_crime': 18,
#   'prop_crime': 82,
#   'lat': 39.676163,
#   'long': -89.7045439},
#  {'city': 'Cowden',
#   'race_w': 996,
#   'race_aa': 6,
#   'eth_hisp': 14,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 5,
#   'lat': 39.2483753,
#   'long': -88.8622895},
#  {'city': 'Saint Jacob',
#   'race_w': 2706,
#   'race_aa': 12,
#   'eth_hisp': 26,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.7139365,
#   'long': -89.7681496},
#  {'city': 'Atkinson',
#   'race_w': 1509,
#   'race_aa': 4,
#   'eth_hisp': 13,
#   'median_income': 58636.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.4208678,
#   'long': -90.0151121},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 41.9166949,
#   'long': -88.1975725},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 41.9166949,
#   'long': -88.1975725},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 41.9166949,
#   'long': -88.1975725},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 42.22919,
#   'long': -88.355086},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 42.22919,
#   'long': -88.355086},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 42.22919,
#   'long': -88.355086},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 39.325041,
#   'long': -88.8995161},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 39.325041,
#   'long': -88.8995161},
#  {'city': 'Lakewood',
#   'race_w': 300,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 21,
#   'lat': 39.325041,
#   'long': -88.8995161},
#  {'city': 'Yates City',
#   'race_w': 1186,
#   'race_aa': 32,
#   'eth_hisp': 0,
#   'median_income': 56607.0,
#   'vio_crime': 1,
#   'prop_crime': 8,
#   'lat': 40.7786485,
#   'long': -90.0148371},
#  {'city': 'Armington',
#   'race_w': 588,
#   'race_aa': 0,
#   'eth_hisp': 15,
#   'median_income': 71111.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.3389293,
#   'long': -89.3114813},
#  {'city': 'Steger',
#   'race_w': 6482,
#   'race_aa': 2517,
#   'eth_hisp': 1491,
#   'median_income': 47516.0,
#   'vio_crime': 25,
#   'prop_crime': 247,
#   'lat': 41.4700348,
#   'long': -87.636432},
#  {'city': 'Willow Springs',
#   'race_w': 4789,
#   'race_aa': 183,
#   'eth_hisp': 869,
#   'median_income': 83505.0,
#   'vio_crime': 4,
#   'prop_crime': 31,
#   'lat': 41.7408652,
#   'long': -87.8603343},
#  {'city': 'Payson',
#   'race_w': 1918,
#   'race_aa': 0,
#   'eth_hisp': 11,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.8169907,
#   'long': -91.2423657},
#  {'city': 'Yorkville',
#   'race_w': 21503,
#   'race_aa': 1883,
#   'eth_hisp': 3049,
#   'median_income': 95878.0,
#   'vio_crime': 18,
#   'prop_crime': 200,
#   'lat': 41.6411409,
#   'long': -88.4472948},
#  {'city': 'Shipman',
#   'race_w': 2311,
#   'race_aa': 97,
#   'eth_hisp': 35,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.1175462,
#   'long': -90.0442728},
#  {'city': 'Cuba',
#   'race_w': 2122,
#   'race_aa': 92,
#   'eth_hisp': 15,
#   'median_income': 58641.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.4928181,
#   'long': -90.1906768},
#  {'city': 'Abingdon',
#   'race_w': 3865,
#   'race_aa': 55,
#   'eth_hisp': 39,
#   'median_income': 44570.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.8044833,
#   'long': -90.4017954},
#  {'city': 'Polo',
#   'race_w': 3535,
#   'race_aa': 27,
#   'eth_hisp': 125,
#   'median_income': 57525.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.986141,
#   'long': -89.5792782},
#  {'city': 'Morrison',
#   'race_w': 6923,
#   'race_aa': 41,
#   'eth_hisp': 86,
#   'median_income': 57250.0,
#   'vio_crime': 10,
#   'prop_crime': 61,
#   'lat': 41.809751,
#   'long': -89.9651186},
#  {'city': 'Onarga',
#   'race_w': 1322,
#   'race_aa': 37,
#   'eth_hisp': 474,
#   'median_income': 55486.0,
#   'vio_crime': 2,
#   'prop_crime': 12,
#   'lat': 40.715035,
#   'long': -88.0061509},
#  {'city': 'Ashley',
#   'race_w': 1386,
#   'race_aa': 0,
#   'eth_hisp': 50,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.3294942,
#   'long': -89.1909097},
#  {'city': 'Windsor',
#   'race_w': 1912,
#   'race_aa': 0,
#   'eth_hisp': 83,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.2018217,
#   'long': -90.4443594},
#  {'city': 'Windsor',
#   'race_w': 1912,
#   'race_aa': 0,
#   'eth_hisp': 83,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.2018217,
#   'long': -90.4443594},
#  {'city': 'Windsor',
#   'race_w': 1912,
#   'race_aa': 0,
#   'eth_hisp': 83,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.4408693,
#   'long': -88.5947802},
#  {'city': 'Windsor',
#   'race_w': 1912,
#   'race_aa': 0,
#   'eth_hisp': 83,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.4408693,
#   'long': -88.5947802},
#  {'city': 'Radom',
#   'race_w': 154,
#   'race_aa': 0,
#   'eth_hisp': 5,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.2819943,
#   'long': -89.1922994},
#  {'city': 'Justice',
#   'race_w': 11405,
#   'race_aa': 3033,
#   'eth_hisp': 3310,
#   'median_income': 50371.0,
#   'vio_crime': 7,
#   'prop_crime': 29,
#   'lat': 41.7444765,
#   'long': -87.8378337},
#  {'city': 'Steeleville',
#   'race_w': 2996,
#   'race_aa': 94,
#   'eth_hisp': 11,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.007273,
#   'long': -89.6584326},
#  {'city': 'Cypress',
#   'race_w': 460,
#   'race_aa': 44,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.3650516,
#   'long': -89.0181271},
#  {'city': 'Matteson',
#   'race_w': 4938,
#   'race_aa': 16210,
#   'eth_hisp': 1091,
#   'median_income': 73544.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.5039235,
#   'long': -87.7131018},
#  {'city': 'Milledgeville',
#   'race_w': 1670,
#   'race_aa': 66,
#   'eth_hisp': 81,
#   'median_income': 58315.0,
#   'vio_crime': 1,
#   'prop_crime': 9,
#   'lat': 41.9633615,
#   'long': -89.7745604},
#  {'city': 'Maquon',
#   'race_w': 669,
#   'race_aa': 0,
#   'eth_hisp': 21,
#   'median_income': 56354.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.798927,
#   'long': -90.1656764},
#  {'city': 'Aledo',
#   'race_w': 5118,
#   'race_aa': 54,
#   'eth_hisp': 80,
#   'median_income': 53859.0,
#   'vio_crime': 0,
#   'prop_crime': 26,
#   'lat': 41.1997568,
#   'long': -90.7493063},
#  {'city': 'Machesney Park',
#   'race_w': 21297,
#   'race_aa': 729,
#   'eth_hisp': 1340,
#   'median_income': 60213.0,
#   'vio_crime': 57,
#   'prop_crime': 416,
#   'lat': 42.3472406,
#   'long': -89.0389956},
#  {'city': 'Hampton',
#   'race_w': 1886,
#   'race_aa': 116,
#   'eth_hisp': 139,
#   'median_income': 68485.0,
#   'vio_crime': 2,
#   'prop_crime': 9,
#   'lat': 41.5558667,
#   'long': -90.4092971},
#  {'city': 'Fox Lake',
#   'race_w': 9312,
#   'race_aa': 135,
#   'eth_hisp': 854,
#   'median_income': 57518.0,
#   'vio_crime': 17,
#   'prop_crime': 256,
#   'lat': 42.3966874,
#   'long': -88.1836965},
#  {'city': 'Leonore',
#   'race_w': 71,
#   'race_aa': 0,
#   'eth_hisp': 6,
#   'median_income': 66250.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.1894788,
#   'long': -88.9806354},
#  {'city': 'Belleville',
#   'race_w': 69776,
#   'race_aa': 22583,
#   'eth_hisp': 3147,
#   'median_income': nan,
#   'vio_crime': 171,
#   'prop_crime': 1261,
#   'lat': 38.5200504,
#   'long': -89.9839935},
#  {'city': 'Hillside',
#   'race_w': 2797,
#   'race_aa': 3943,
#   'eth_hisp': 2586,
#   'median_income': 53728.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.8778084,
#   'long': -87.9028398},
#  {'city': 'Waverly',
#   'race_w': 2096,
#   'race_aa': 23,
#   'eth_hisp': 2,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 11,
#   'lat': 39.5917159,
#   'long': -89.9528847},
#  {'city': 'Marietta',
#   'race_w': 359,
#   'race_aa': 26,
#   'eth_hisp': 1,
#   'median_income': 72992.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.5011518,
#   'long': -90.3926259},
#  {'city': 'Braidwood',
#   'race_w': 5610,
#   'race_aa': 54,
#   'eth_hisp': 258,
#   'median_income': 65559.0,
#   'vio_crime': 11,
#   'prop_crime': 45,
#   'lat': 41.2650318,
#   'long': -88.2122823},
#  {'city': 'Elizabeth',
#   'race_w': 2024,
#   'race_aa': 17,
#   'eth_hisp': 15,
#   'median_income': 49189.0,
#   'vio_crime': 0,
#   'prop_crime': 5,
#   'lat': 42.3177911,
#   'long': -90.221517},
#  {'city': 'Raleigh',
#   'race_w': 743,
#   'race_aa': 0,
#   'eth_hisp': 9,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.8269921,
#   'long': -88.5319958},
#  {'city': 'Beaverville',
#   'race_w': 487,
#   'race_aa': 20,
#   'eth_hisp': 12,
#   'median_income': 45313.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.954478,
#   'long': -87.6544781},
#  {'city': 'Fairview',
#   'race_w': 647,
#   'race_aa': 5,
#   'eth_hisp': 32,
#   'median_income': 72188.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.6333724,
#   'long': -90.1637318},
#  {'city': 'Ramsey',
#   'race_w': 2425,
#   'race_aa': 8,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.1444882,
#   'long': -89.108685},
#  {'city': 'Elkville',
#   'race_w': 1430,
#   'race_aa': 28,
#   'eth_hisp': 65,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.9100505,
#   'long': -89.2359165},
#  {'city': 'Oakland',
#   'race_w': 1658,
#   'race_aa': 0,
#   'eth_hisp': 60,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.6539235,
#   'long': -88.0261471},
#  {'city': 'Roberts',
#   'race_w': 632,
#   'race_aa': 10,
#   'eth_hisp': 22,
#   'median_income': 42083.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.6128127,
#   'long': -88.1833798},
#  {'city': 'Redmon',
#   'race_w': 131,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.6453126,
#   'long': -87.8616975},
#  {'city': 'Creston',
#   'race_w': 284,
#   'race_aa': 12,
#   'eth_hisp': 67,
#   'median_income': 60156.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.9308618,
#   'long': -88.9645382},
#  {'city': 'Virginia',
#   'race_w': 1919,
#   'race_aa': 14,
#   'eth_hisp': 66,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.9511595,
#   'long': -90.2123427},
#  {'city': 'Athens',
#   'race_w': 3819,
#   'race_aa': 67,
#   'eth_hisp': 32,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 16,
#   'lat': 39.9608826,
#   'long': -89.7239944},
#  {'city': 'Mokena',
#   'race_w': 25650,
#   'race_aa': 377,
#   'eth_hisp': 1498,
#   'median_income': 104327.0,
#   'vio_crime': 11,
#   'prop_crime': 295,
#   'lat': 41.5261437,
#   'long': -87.8892189},
#  {'city': 'Colchester',
#   'race_w': 2337,
#   'race_aa': 0,
#   'eth_hisp': 1,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 1,
#   'lat': 40.4264306,
#   'long': -90.7926324},
#  {'city': 'Bethany',
#   'race_w': 1833,
#   'race_aa': 0,
#   'eth_hisp': 1,
#   'median_income': nan,
#   'vio_crime': 1,
#   'prop_crime': 11,
#   'lat': 39.6455916,
#   'long': -88.7381252},
#  {'city': 'Rio',
#   'race_w': 506,
#   'race_aa': 10,
#   'eth_hisp': 37,
#   'median_income': 72727.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.1092036,
#   'long': -90.399851},
#  {'city': 'East Dubuque',
#   'race_w': 4563,
#   'race_aa': 58,
#   'eth_hisp': 25,
#   'median_income': 62208.0,
#   'vio_crime': 3,
#   'prop_crime': 17,
#   'lat': 42.4922253,
#   'long': -90.6429054},
#  {'city': 'Minooka',
#   'race_w': 13204,
#   'race_aa': 355,
#   'eth_hisp': 2395,
#   'median_income': 75485.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.4553084,
#   'long': -88.2617305},
#  {'city': 'Garden Prairie',
#   'race_w': 1149,
#   'race_aa': 0,
#   'eth_hisp': 76,
#   'median_income': 79598.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.25083426,
#   'long': -88.71988959},
#  {'city': 'Peoria Heights',
#   'race_w': 5577,
#   'race_aa': 734,
#   'eth_hisp': 102,
#   'median_income': 44037.0,
#   'vio_crime': 18,
#   'prop_crime': 90,
#   'lat': 40.7472594,
#   'long': -89.5739845},
#  {'city': 'Willowbrook',
#   'race_w': 21810,
#   'race_aa': 2324,
#   'eth_hisp': 1371,
#   'median_income': 94060.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.7697533,
#   'long': -87.9358931},
#  {'city': 'Willowbrook',
#   'race_w': 21810,
#   'race_aa': 2324,
#   'eth_hisp': 1371,
#   'median_income': 94060.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.7697533,
#   'long': -87.9358931},
#  {'city': 'Willowbrook',
#   'race_w': 21810,
#   'race_aa': 2324,
#   'eth_hisp': 1371,
#   'median_income': 94060.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.457813,
#   'long': -87.5364288},
#  {'city': 'Willowbrook',
#   'race_w': 21810,
#   'race_aa': 2324,
#   'eth_hisp': 1371,
#   'median_income': 94060.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.457813,
#   'long': -87.5364288},
#  {'city': 'Atlanta',
#   'race_w': 2568,
#   'race_aa': 2,
#   'eth_hisp': 118,
#   'median_income': 64453.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.2594846,
#   'long': -89.2334236},
#  {'city': 'Neoga',
#   'race_w': 3581,
#   'race_aa': 46,
#   'eth_hisp': 69,
#   'median_income': nan,
#   'vio_crime': 3,
#   'prop_crime': 12,
#   'lat': 39.3194817,
#   'long': -88.4528261},
#  {'city': 'Monee',
#   'race_w': 7323,
#   'race_aa': 1559,
#   'eth_hisp': 785,
#   'median_income': 74568.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.420034,
#   'long': -87.7417115},
#  {'city': 'Carterville',
#   'race_w': 9414,
#   'race_aa': 550,
#   'eth_hisp': 485,
#   'median_income': nan,
#   'vio_crime': 13,
#   'prop_crime': 58,
#   'lat': 37.7600501,
#   'long': -89.0772991},
#  {'city': 'Andalusia',
#   'race_w': 1209,
#   'race_aa': 27,
#   'eth_hisp': 10,
#   'median_income': 64500.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.4391986,
#   'long': -90.717641},
#  {'city': 'Muncie',
#   'race_w': 195,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': 32500.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.1155911,
#   'long': -87.844751},
#  {'city': 'Kansas',
#   'race_w': 901,
#   'race_aa': 0,
#   'eth_hisp': 5,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.5528129,
#   'long': -87.9394779},
#  {'city': 'Ashmore',
#   'race_w': 1222,
#   'race_aa': 6,
#   'eth_hisp': 5,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.5330909,
#   'long': -88.0222582},
#  {'city': 'Lyndon',
#   'race_w': 919,
#   'race_aa': 0,
#   'eth_hisp': 16,
#   'median_income': 44792.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.7175302,
#   'long': -89.9259481},
#  {'city': 'Industry',
#   'race_w': 686,
#   'race_aa': 0,
#   'eth_hisp': 8,
#   'median_income': 64063.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.3278211,
#   'long': -90.607073},
#  {'city': 'Argenta',
#   'race_w': 2851,
#   'race_aa': 48,
#   'eth_hisp': 18,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.9819808,
#   'long': -88.8228535},
#  {'city': 'West Brooklyn',
#   'race_w': 333,
#   'race_aa': 0,
#   'eth_hisp': 2,
#   'median_income': 47000.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.6928094,
#   'long': -89.1470351},
#  {'city': 'Calhoun',
#   'race_w': 230,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.6503262,
#   'long': -88.0436473},
#  {'city': 'South Wilmington',
#   'race_w': 986,
#   'race_aa': 0,
#   'eth_hisp': 53,
#   'median_income': 69688.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.17281,
#   'long': -88.276726},
#  {'city': 'South Pekin',
#   'race_w': 959,
#   'race_aa': 6,
#   'eth_hisp': 3,
#   'median_income': 49934.0,
#   'vio_crime': 0,
#   'prop_crime': 36,
#   'lat': 40.4944838,
#   'long': -89.6517711},
#  {'city': 'Mendon',
#   'race_w': 1854,
#   'race_aa': 25,
#   'eth_hisp': 49,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.0883795,
#   'long': -91.2837565},
#  {'city': 'Cambridge',
#   'race_w': 3414,
#   'race_aa': 80,
#   'eth_hisp': 45,
#   'median_income': 62132.0,
#   'vio_crime': 2,
#   'prop_crime': 7,
#   'lat': 41.3036472,
#   'long': -90.1928971},
#  {'city': 'Berwyn',
#   'race_w': 37987,
#   'race_aa': 4595,
#   'eth_hisp': 39477,
#   'median_income': 60814.0,
#   'vio_crime': 191,
#   'prop_crime': 818,
#   'lat': 41.8505874,
#   'long': -87.7936685},
#  {'city': 'Cordova',
#   'race_w': 1192,
#   'race_aa': 12,
#   'eth_hisp': 23,
#   'median_income': 69867.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.6803099,
#   'long': -90.319018},
#  {'city': 'Seneca',
#   'race_w': 3661,
#   'race_aa': 4,
#   'eth_hisp': 219,
#   'median_income': 71198.0,
#   'vio_crime': 13,
#   'prop_crime': 40,
#   'lat': 41.3111442,
#   'long': -88.6097936},
#  {'city': 'Indianola',
#   'race_w': 416,
#   'race_aa': 10,
#   'eth_hisp': 2,
#   'median_income': 53929.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.927258,
#   'long': -87.740025},
#  {'city': 'Rankin',
#   'race_w': 1072,
#   'race_aa': 6,
#   'eth_hisp': 98,
#   'median_income': 56683.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.4650357,
#   'long': -87.8964219},
#  {'city': 'Bonfield',
#   'race_w': 1338,
#   'race_aa': 31,
#   'eth_hisp': 41,
#   'median_income': 72266.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.1466986,
#   'long': -88.0578276},
#  {'city': 'Anchor',
#   'race_w': 201,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': 60625.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.5680898,
#   'long': -88.5356146},
#  {'city': 'Addieville',
#   'race_w': 1232,
#   'race_aa': 0,
#   'eth_hisp': 18,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.391439,
#   'long': -89.4900881},
#  {'city': 'Modesto',
#   'race_w': 437,
#   'race_aa': 8,
#   'eth_hisp': 2,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.4783816,
#   'long': -89.982051},
#  {'city': 'Harmon',
#   'race_w': 578,
#   'race_aa': 10,
#   'eth_hisp': 20,
#   'median_income': 49318.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.722811,
#   'long': -89.5539905},
#  {'city': 'Tonica',
#   'race_w': 1384,
#   'race_aa': 0,
#   'eth_hisp': 93,
#   'median_income': 59583.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.2158684,
#   'long': -89.0667489},
#  {'city': 'Topeka',
#   'race_w': 540,
#   'race_aa': 16,
#   'eth_hisp': 0,
#   'median_income': 38750.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.3303196,
#   'long': -89.9312252},
#  {'city': 'Panama',
#   'race_w': 240,
#   'race_aa': 0,
#   'eth_hisp': 5,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.0294908,
#   'long': -89.5242529},
#  {'city': 'Breese',
#   'race_w': 6215,
#   'race_aa': 5,
#   'eth_hisp': 89,
#   'median_income': nan,
#   'vio_crime': 2,
#   'prop_crime': 28,
#   'lat': 38.6106042,
#   'long': -89.5270306},
#  {'city': 'Mount Carmel',
#   'race_w': 9552,
#   'race_aa': 126,
#   'eth_hisp': 230,
#   'median_income': nan,
#   'vio_crime': 17,
#   'prop_crime': 123,
#   'lat': 38.4108801,
#   'long': -87.7614174},
#  {'city': 'Albany',
#   'race_w': 1119,
#   'race_aa': 0,
#   'eth_hisp': 47,
#   'median_income': 55000.0,
#   'vio_crime': 1,
#   'prop_crime': 6,
#   'lat': 41.7894748,
#   'long': -90.2192941},
#  {'city': 'Crossville',
#   'race_w': 1153,
#   'race_aa': 10,
#   'eth_hisp': 8,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.1617133,
#   'long': -88.0653123},
#  {'city': 'Granite City',
#   'race_w': 38655,
#   'race_aa': 3170,
#   'eth_hisp': 2800,
#   'median_income': nan,
#   'vio_crime': 219,
#   'prop_crime': 729,
#   'lat': 38.7014389,
#   'long': -90.1487199},
#  {'city': 'Sugar Grove',
#   'race_w': 10961,
#   'race_aa': 631,
#   'eth_hisp': 846,
#   'median_income': 111558.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.7614181,
#   'long': -88.443686},
#  {'city': 'Eldred',
#   'race_w': 469,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.2875475,
#   'long': -90.5523438},
#  {'city': 'Batavia',
#   'race_w': 27552,
#   'race_aa': 840,
#   'eth_hisp': 2248,
#   'median_income': 95026.0,
#   'vio_crime': 34,
#   'prop_crime': 369,
#   'lat': 41.8500284,
#   'long': -88.3125738},
#  {'city': 'Geneva',
#   'race_w': 28594,
#   'race_aa': 97,
#   'eth_hisp': 1662,
#   'median_income': 117951.0,
#   'vio_crime': 6,
#   'prop_crime': 154,
#   'lat': 41.8875281,
#   'long': -88.3053525},
#  {'city': 'Mundelein',
#   'race_w': 30081,
#   'race_aa': 737,
#   'eth_hisp': 11902,
#   'median_income': 93108.0,
#   'vio_crime': 27,
#   'prop_crime': 183,
#   'lat': 42.263079,
#   'long': -88.0039653},
#  {'city': 'Herscher',
#   'race_w': 2161,
#   'race_aa': 64,
#   'eth_hisp': 30,
#   'median_income': 74444.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.0491989,
#   'long': -88.0978262},
#  {'city': 'Saint Anne',
#   'race_w': 4350,
#   'race_aa': 667,
#   'eth_hisp': 549,
#   'median_income': 53723.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.0250329,
#   'long': -87.7139249},
#  {'city': 'Northbrook',
#   'race_w': 33430,
#   'race_aa': 850,
#   'eth_hisp': 1265,
#   'median_income': 110012.0,
#   'vio_crime': 6,
#   'prop_crime': 512,
#   'lat': 42.1275267,
#   'long': -87.8289548},
#  {'city': 'Dennison',
#   'race_w': 485,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.4608688,
#   'long': -87.5978025},
#  {'city': 'Buckner',
#   'race_w': 408,
#   'race_aa': 0,
#   'eth_hisp': 3,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.9831056,
#   'long': -89.0161841},
#  {'city': 'White Hall',
#   'race_w': 2900,
#   'race_aa': 43,
#   'eth_hisp': 39,
#   'median_income': nan,
#   'vio_crime': 8,
#   'prop_crime': 30,
#   'lat': 39.4369917,
#   'long': -90.403177},
#  {'city': 'El Paso',
#   'race_w': 4294,
#   'race_aa': 160,
#   'eth_hisp': 21,
#   'median_income': 71857.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.7392018,
#   'long': -89.0164626},
#  {'city': 'Summerfield',
#   'race_w': 345,
#   'race_aa': 0,
#   'eth_hisp': 31,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.5972705,
#   'long': -89.751762},
#  {'city': 'Avon',
#   'race_w': 1887,
#   'race_aa': 8,
#   'eth_hisp': 4,
#   'median_income': 56667.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.6642065,
#   'long': -90.4348506},
#  {'city': 'Oblong',
#   'race_w': 3060,
#   'race_aa': 56,
#   'eth_hisp': 54,
#   'median_income': nan,
#   'vio_crime': 3,
#   'prop_crime': 10,
#   'lat': 39.0019867,
#   'long': -87.9089205},
#  {'city': 'Green Valley',
#   'race_w': 1796,
#   'race_aa': 9,
#   'eth_hisp': 25,
#   'median_income': 57917.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.4075408,
#   'long': -89.6428829},
#  {'city': 'Pleasant Hill',
#   'race_w': 1556,
#   'race_aa': 0,
#   'eth_hisp': 13,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 24,
#   'lat': 39.4433806,
#   'long': -90.8723527},
#  {'city': 'Ina',
#   'race_w': 1834,
#   'race_aa': 878,
#   'eth_hisp': 272,
#   'median_income': nan,
#   'vio_crime': 4,
#   'prop_crime': 9,
#   'lat': 38.1511606,
#   'long': -88.9039554},
#  {'city': 'Bensenville',
#   'race_w': 16102,
#   'race_aa': 968,
#   'eth_hisp': 9718,
#   'median_income': 63486.0,
#   'vio_crime': 20,
#   'prop_crime': 272,
#   'lat': 41.9550296,
#   'long': -87.9400657},
#  {'city': 'Walshville',
#   'race_w': 380,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.0708801,
#   'long': -89.6189784},
#  {'city': 'Teutopolis',
#   'race_w': 4275,
#   'race_aa': 6,
#   'eth_hisp': 3,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.1330967,
#   'long': -88.4719918},
#  {'city': 'Oak Park',
#   'race_w': 38528,
#   'race_aa': 10694,
#   'eth_hisp': 4580,
#   'median_income': 91694.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.8850317,
#   'long': -87.7845025},
#  {'city': 'Dalzell',
#   'race_w': 655,
#   'race_aa': 22,
#   'eth_hisp': 42,
#   'median_income': 54000.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.3578126,
#   'long': -89.176196},
#  {'city': 'Riverton',
#   'race_w': 5289,
#   'race_aa': 53,
#   'eth_hisp': 18,
#   'median_income': nan,
#   'vio_crime': 12,
#   'prop_crime': 41,
#   'lat': 39.8442164,
#   'long': -89.5395417},
#  {'city': 'Broadview',
#   'race_w': 1416,
#   'race_aa': 6165,
#   'eth_hisp': 268,
#   'median_income': 49236.0,
#   'vio_crime': 19,
#   'prop_crime': 330,
#   'lat': 41.8639201,
#   'long': -87.8533931},
#  {'city': 'Harvel',
#   'race_w': 356,
#   'race_aa': 0,
#   'eth_hisp': 10,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.3561613,
#   'long': -89.5323151},
#  {'city': 'Moline',
#   'race_w': 38136,
#   'race_aa': 3419,
#   'eth_hisp': 7283,
#   'median_income': 52635.0,
#   'vio_crime': 228,
#   'prop_crime': 1050,
#   'lat': 41.5067003,
#   'long': -90.5151342},
#  {'city': 'Carthage',
#   'race_w': 3790,
#   'race_aa': 49,
#   'eth_hisp': 112,
#   'median_income': nan,
#   'vio_crime': 2,
#   'prop_crime': 23,
#   'lat': 40.416433,
#   'long': -91.1362537},
#  {'city': 'Hurst',
#   'race_w': 821,
#   'race_aa': 53,
#   'eth_hisp': 7,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.8331059,
#   'long': -89.1428573},
#  {'city': 'Malta',
#   'race_w': 1673,
#   'race_aa': 14,
#   'eth_hisp': 180,
#   'median_income': 68250.0,
#   'vio_crime': 0,
#   'prop_crime': 2,
#   'lat': 41.929751,
#   'long': -88.8609238},
#  {'city': 'Mount Vernon',
#   'race_w': 20689,
#   'race_aa': 2876,
#   'eth_hisp': 564,
#   'median_income': nan,
#   'vio_crime': 228,
#   'prop_crime': 773,
#   'lat': 38.3172715,
#   'long': -88.9031201},
#  {'city': 'Edinburg',
#   'race_w': 1746,
#   'race_aa': 18,
#   'eth_hisp': 18,
#   'median_income': nan,
#   'vio_crime': 14,
#   'prop_crime': 12,
#   'lat': 39.6572697,
#   'long': -89.3895338},
#  {'city': 'Griggsville',
#   'race_w': 1871,
#   'race_aa': 11,
#   'eth_hisp': 90,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.7089362,
#   'long': -90.7245722},
#  {'city': 'Willow Hill',
#   'race_w': 463,
#   'race_aa': 7,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.9958759,
# ...
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.7011516,
#   'long': -89.1231356},
#  {'city': 'Livingston',
#   'race_w': 732,
#   'race_aa': 0,
#   'eth_hisp': 8,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.9675463,
#   'long': -89.7639828},
#  {'city': 'Alton',
#   'race_w': 24328,
#   'race_aa': 7077,
#   'eth_hisp': 720,
#   'median_income': nan,
#   'vio_crime': 171,
#   'prop_crime': 994,
#   'lat': 38.8906038,
#   'long': -90.1842764},
#  {'city': 'Donovan',
#   'race_w': 535,
#   'race_aa': 37,
#   'eth_hisp': 16,
#   'median_income': 55000.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.883368,
#   'long': -87.6161428},
#  {'city': 'Cobden',
#   'race_w': 3142,
#   'race_aa': 113,
#   'eth_hisp': 477,
#   'median_income': nan,
#   'vio_crime': 6,
#   'prop_crime': 8,
#   'lat': 37.5314386,
#   'long': -89.253418},
#  {'city': 'Auburn',
#   'race_w': 5516,
#   'race_aa': 191,
#   'eth_hisp': 117,
#   'median_income': nan,
#   'vio_crime': 2,
#   'prop_crime': 7,
#   'lat': 39.5917197,
#   'long': -89.7464874},
#  {'city': 'Sciota',
#   'race_w': 203,
#   'race_aa': 2,
#   'eth_hisp': 0,
#   'median_income': 76563.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.5608731,
#   'long': -90.7517996},
#  {'city': 'Rantoul',
#   'race_w': 10544,
#   'race_aa': 3128,
#   'eth_hisp': 1554,
#   'median_income': nan,
#   'vio_crime': 35,
#   'prop_crime': 349,
#   'lat': 40.3083672,
#   'long': -88.1558785},
#  {'city': 'Chrisman',
#   'race_w': 2238,
#   'race_aa': 26,
#   'eth_hisp': 12,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.8036467,
#   'long': -87.673635},
#  {'city': 'Forrest',
#   'race_w': 1690,
#   'race_aa': 12,
#   'eth_hisp': 77,
#   'median_income': 70385.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.7519792,
#   'long': -88.4111647},
#  {'city': 'Poplar Grove',
#   'race_w': 9637,
#   'race_aa': 562,
#   'eth_hisp': 1052,
#   'median_income': 70056.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.3683522,
#   'long': -88.822047},
#  {'city': 'Orland Park',
#   'race_w': 59552,
#   'race_aa': 2358,
#   'eth_hisp': 4998,
#   'median_income': 90841.0,
#   'vio_crime': 20,
#   'prop_crime': 1015,
#   'lat': 41.6303103,
#   'long': -87.8539425},
#  {'city': 'Glendale Heights',
#   'race_w': 19839,
#   'race_aa': 3400,
#   'eth_hisp': 10753,
#   'median_income': 65865.0,
#   'vio_crime': 18,
#   'prop_crime': 397,
#   'lat': 41.9103068,
#   'long': -88.0717353},
#  {'city': 'Bradley',
#   'race_w': 9177,
#   'race_aa': 481,
#   'eth_hisp': 1356,
#   'median_income': 55152.0,
#   'vio_crime': 17,
#   'prop_crime': 442,
#   'lat': 41.1419768,
#   'long': -87.8611535},
#  {'city': 'Ivesdale',
#   'race_w': 295,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': 64167.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.9433658,
#   'long': -88.4553363},
#  {'city': 'Cambria',
#   'race_w': 397,
#   'race_aa': 0,
#   'eth_hisp': 38,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.7814392,
#   'long': -89.1192454},
#  {'city': 'Carbondale',
#   'race_w': 24245,
#   'race_aa': 7964,
#   'eth_hisp': 1917,
#   'median_income': nan,
#   'vio_crime': 111,
#   'prop_crime': 760,
#   'lat': 37.7272727,
#   'long': -89.2167501},
#  {'city': 'Wauconda',
#   'race_w': 14554,
#   'race_aa': 141,
#   'eth_hisp': 3365,
#   'median_income': 80529.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.2589122,
#   'long': -88.1392474},
#  {'city': 'Plano',
#   'race_w': 11348,
#   'race_aa': 1478,
#   'eth_hisp': 3754,
#   'median_income': 72542.0,
#   'vio_crime': 9,
#   'prop_crime': 72,
#   'lat': 41.6628076,
#   'long': -88.5370197},
#  {'city': 'Karnak',
#   'race_w': 884,
#   'race_aa': 16,
#   'eth_hisp': 11,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 37.2936633,
#   'long': -88.9753462},
#  {'city': 'Fulton',
#   'race_w': 5268,
#   'race_aa': 28,
#   'eth_hisp': 47,
#   'median_income': 59572.0,
#   'vio_crime': 9,
#   'prop_crime': 48,
#   'lat': 41.8672508,
#   'long': -90.1595705},
#  {'city': 'Warsaw',
#   'race_w': 1717,
#   'race_aa': 0,
#   'eth_hisp': 76,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.359211,
#   'long': -91.4345978},
#  {'city': 'Dalton City',
#   'race_w': 670,
#   'race_aa': 11,
#   'eth_hisp': 9,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.7119804,
#   'long': -88.8045162},
#  {'city': 'Villa Park',
#   'race_w': 23324,
#   'race_aa': 1850,
#   'eth_hisp': 6476,
#   'median_income': 69488.0,
#   'vio_crime': 27,
#   'prop_crime': 232,
#   'lat': 41.8897519,
#   'long': -87.9889543},
#  {'city': 'Tovey',
#   'race_w': 514,
#   'race_aa': 0,
#   'eth_hisp': 10,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.5889391,
#   'long': -89.4562045},
#  {'city': 'South Holland',
#   'race_w': 3768,
#   'race_aa': 18020,
#   'eth_hisp': 1058,
#   'median_income': 62951.0,
#   'vio_crime': 68,
#   'prop_crime': 541,
#   'lat': 41.6008681,
#   'long': -87.6069894},
#  {'city': 'Secor',
#   'race_w': 737,
#   'race_aa': 0,
#   'eth_hisp': 9,
#   'median_income': 92574.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.7419799,
#   'long': -89.1353567},
#  {'city': 'Hometown',
#   'race_w': 4096,
#   'race_aa': 110,
#   'eth_hisp': 699,
#   'median_income': 49359.0,
#   'vio_crime': 3,
#   'prop_crime': 15,
#   'lat': 41.7344774,
#   'long': -87.731441},
#  {'city': 'Freeburg',
#   'race_w': 5702,
#   'race_aa': 45,
#   'eth_hisp': 138,
#   'median_income': nan,
#   'vio_crime': 2,
#   'prop_crime': 29,
#   'lat': 38.4275499,
#   'long': -89.913714},
#  {'city': 'Carbon Cliff',
#   'race_w': 827,
#   'race_aa': 412,
#   'eth_hisp': 75,
#   'median_income': 34033.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.4947564,
#   'long': -90.3906844},
#  {'city': 'Williamsville',
#   'race_w': 1503,
#   'race_aa': 0,
#   'eth_hisp': 8,
#   'median_income': nan,
#   'vio_crime': 2,
#   'prop_crime': 2,
#   'lat': 39.9542161,
#   'long': -89.5487126},
#  {'city': 'Pecatonica',
#   'race_w': 4253,
#   'race_aa': 71,
#   'eth_hisp': 51,
#   'median_income': 69306.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.3139078,
#   'long': -89.3592788},
#  {'city': 'Ransom',
#   'race_w': 497,
#   'race_aa': 0,
#   'eth_hisp': 11,
#   'median_income': 82500.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.1561445,
#   'long': -88.6495133},
#  {'city': 'Homewood',
#   'race_w': 10657,
#   'race_aa': 8901,
#   'eth_hisp': 1096,
#   'median_income': 73251.0,
#   'vio_crime': 46,
#   'prop_crime': 786,
#   'lat': 41.5572567,
#   'long': -87.6656015},
#  {'city': 'Lomax',
#   'race_w': 500,
#   'race_aa': 5,
#   'eth_hisp': 21,
#   'median_income': 38750.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.67893,
#   'long': -91.072921},
#  {'city': 'Washburn',
#   'race_w': 1781,
#   'race_aa': 21,
#   'eth_hisp': 25,
#   'median_income': 52688.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.919202,
#   'long': -89.2911973},
#  {'city': 'Newark',
#   'race_w': 3639,
#   'race_aa': 27,
#   'eth_hisp': 99,
#   'median_income': 85179.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.536975,
#   'long': -88.5834068},
#  {'city': 'Stone Park',
#   'race_w': 2459,
#   'race_aa': 173,
#   'eth_hisp': 4360,
#   'median_income': 59022.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.9055862,
#   'long': -87.8836732},
#  {'city': 'Hanover Park',
#   'race_w': 22070,
#   'race_aa': 2764,
#   'eth_hisp': 15347,
#   'median_income': 74883.0,
#   'vio_crime': 43,
#   'prop_crime': 194,
#   'lat': 41.9994722,
#   'long': -88.1450735},
#  {'city': 'Loami',
#   'race_w': 1517,
#   'race_aa': 10,
#   'eth_hisp': 57,
#   'median_income': nan,
#   'vio_crime': 1,
#   'prop_crime': 13,
#   'lat': 39.6756064,
#   'long': -89.846771},
#  {'city': 'Kinsman',
#   'race_w': 183,
#   'race_aa': 0,
#   'eth_hisp': 3,
#   'median_income': 47031.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.1897554,
#   'long': -88.569512},
#  {'city': 'Nokomis',
#   'race_w': 3628,
#   'race_aa': 22,
#   'eth_hisp': 20,
#   'median_income': nan,
#   'vio_crime': 9,
#   'prop_crime': 31,
#   'lat': 39.3011566,
#   'long': -89.285085},
#  {'city': 'Ingraham',
#   'race_w': 317,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.8361573,
#   'long': -88.333933},
#  {'city': 'Victoria',
#   'race_w': 447,
#   'race_aa': 0,
#   'eth_hisp': 4,
#   'median_income': 48684.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.0336485,
#   'long': -90.0984504},
#  {'city': 'Palatine',
#   'race_w': 56080,
#   'race_aa': 2418,
#   'eth_hisp': 15483,
#   'median_income': 82612.0,
#   'vio_crime': 28,
#   'prop_crime': 358,
#   'lat': 42.1103041,
#   'long': -88.03424},
#  {'city': 'Chana',
#   'race_w': 1105,
#   'race_aa': 0,
#   'eth_hisp': 2,
#   'median_income': 81250.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.9805848,
#   'long': -89.2198238},
#  {'city': 'Westchester',
#   'race_w': 11695,
#   'race_aa': 3065,
#   'eth_hisp': 3575,
#   'median_income': 80412.0,
#   'vio_crime': 19,
#   'prop_crime': 172,
#   'lat': 41.8505866,
#   'long': -87.8820048},
#  {'city': 'Hartsburg',
#   'race_w': 561,
#   'race_aa': 2,
#   'eth_hisp': 17,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.2508762,
#   'long': -89.440933},
#  {'city': 'Hartford',
#   'race_w': 1823,
#   'race_aa': 0,
#   'eth_hisp': 5,
#   'median_income': nan,
#   'vio_crime': 2,
#   'prop_crime': 24,
#   'lat': 38.8333815,
#   'long': -90.09594},
#  {'city': 'Owaneco',
#   'race_w': 423,
#   'race_aa': 2,
#   'eth_hisp': 3,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.4822664,
#   'long': -89.1936976},
#  {'city': 'Wonder Lake',
#   'race_w': 10678,
#   'race_aa': 64,
#   'eth_hisp': 1019,
#   'median_income': 72719.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.3852983,
#   'long': -88.3473126},
#  {'city': 'Deer Grove',
#   'race_w': 248,
#   'race_aa': 0,
#   'eth_hisp': 1,
#   'median_income': 100972.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.607811,
#   'long': -89.689547},
#  {'city': 'Saint Libory',
#   'race_w': 400,
#   'race_aa': 0,
#   'eth_hisp': 2,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.3625488,
#   'long': -89.7098187},
#  {'city': 'Fithian',
#   'race_w': 704,
#   'race_aa': 12,
#   'eth_hisp': 5,
#   'median_income': 63393.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.1139242,
#   'long': -87.8730857},
#  {'city': 'Annawan',
#   'race_w': 1237,
#   'race_aa': 22,
#   'eth_hisp': 44,
#   'median_income': 54625.0,
#   'vio_crime': 1,
#   'prop_crime': 8,
#   'lat': 41.3972573,
#   'long': -89.9045518},
#  {'city': 'Reddick',
#   'race_w': 706,
#   'race_aa': 16,
#   'eth_hisp': 19,
#   'median_income': 75000.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.0982752,
#   'long': -88.2486749},
#  {'city': 'Hume',
#   'race_w': 436,
#   'race_aa': 3,
#   'eth_hisp': 15,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.7967015,
#   'long': -87.8686414},
#  {'city': 'Cary',
#   'race_w': 24461,
#   'race_aa': 586,
#   'eth_hisp': 2240,
#   'median_income': 98377.0,
#   'vio_crime': 20,
#   'prop_crime': 110,
#   'lat': 42.2119684,
#   'long': -88.2381381},
#  {'city': 'South Beloit',
#   'race_w': 9969,
#   'race_aa': 471,
#   'eth_hisp': 1099,
#   'median_income': 61419.0,
#   'vio_crime': 13,
#   'prop_crime': 102,
#   'lat': 42.4930708,
#   'long': -89.0367764},
#  {'city': 'Prairie City',
#   'race_w': 520,
#   'race_aa': 18,
#   'eth_hisp': 23,
#   'median_income': 47222.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.6211512,
#   'long': -90.4620731},
#  {'city': 'Richton Park',
#   'race_w': 1571,
#   'race_aa': 12225,
#   'eth_hisp': 393,
#   'median_income': 55625.0,
#   'vio_crime': 55,
#   'prop_crime': 331,
#   'lat': 41.484479,
#   'long': -87.7033787},
#  {'city': 'Roscoe',
#   'race_w': 17932,
#   'race_aa': 509,
#   'eth_hisp': 462,
#   'median_income': 84563.0,
#   'vio_crime': 10,
#   'prop_crime': 93,
#   'lat': 42.4133505,
#   'long': -89.0092742},
#  {'city': 'Sawyerville',
#   'race_w': 191,
#   'race_aa': 0,
#   'eth_hisp': 3,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.07838,
#   'long': -89.807318},
#  {'city': 'Dix',
#   'race_w': 1227,
#   'race_aa': 13,
#   'eth_hisp': 14,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.4417157,
#   'long': -88.9375635},
#  {'city': 'Loraine',
#   'race_w': 607,
#   'race_aa': 0,
#   'eth_hisp': 13,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.1542128,
#   'long': -91.2223653},
#  {'city': 'Mineral',
#   'race_w': 371,
#   'race_aa': 2,
#   'eth_hisp': 0,
#   'median_income': 46250.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 41.3825354,
#   'long': -89.8364934},
#  {'city': 'Canton',
#   'race_w': 15498,
#   'race_aa': 1285,
#   'eth_hisp': 788,
#   'median_income': 47362.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.5580945,
#   'long': -90.0351167},
#  {'city': 'Farina',
#   'race_w': 1812,
#   'race_aa': 0,
#   'eth_hisp': 63,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.8342128,
#   'long': -88.7722761},
#  {'city': 'Harrisburg',
#   'race_w': 12019,
#   'race_aa': 752,
#   'eth_hisp': 161,
#   'median_income': nan,
#   'vio_crime': 49,
#   'prop_crime': 325,
#   'lat': 37.7383812,
#   'long': -88.540607},
#  {'city': 'Peru',
#   'race_w': 10289,
#   'race_aa': 158,
#   'eth_hisp': 882,
#   'median_income': 50809.0,
#   'vio_crime': 10,
#   'prop_crime': 149,
#   'lat': 41.3275349,
#   'long': -89.1289728},
#  {'city': 'Orion',
#   'race_w': 3190,
#   'race_aa': 45,
#   'eth_hisp': 53,
#   'median_income': 70766.0,
#   'vio_crime': 3,
#   'prop_crime': 13,
#   'lat': 41.3547575,
#   'long': -90.3815165},
#  {'city': 'Zion',
#   'race_w': 20463,
#   'race_aa': 8481,
#   'eth_hisp': 8837,
#   'median_income': 54685.0,
#   'vio_crime': 148,
#   'prop_crime': 721,
#   'lat': 42.4461322,
#   'long': -87.8328505},
#  {'city': 'Cisne',
#   'race_w': 1688,
#   'race_aa': 8,
#   'eth_hisp': 14,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.5158815,
#   'long': -88.4375481},
#  {'city': 'Saint Augustine',
#   'race_w': 292,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': 51875.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.7183728,
#   'long': -90.4109616},
#  {'city': 'Carrollton',
#   'race_w': 3648,
#   'race_aa': 26,
#   'eth_hisp': 1,
#   'median_income': nan,
#   'vio_crime': 15,
#   'prop_crime': 25,
#   'lat': 39.3022693,
#   'long': -90.4070632},
#  {'city': 'Sadorus',
#   'race_w': 897,
#   'race_aa': 2,
#   'eth_hisp': 3,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.9669758,
#   'long': -88.3464425},
#  {'city': 'Hoyleton',
#   'race_w': 1036,
#   'race_aa': 57,
#   'eth_hisp': 31,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.4417163,
#   'long': -89.2742452},
#  {'city': 'Lake Forest',
#   'race_w': 18890,
#   'race_aa': 520,
#   'eth_hisp': 1013,
#   'median_income': 171913.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.2586342,
#   'long': -87.840625},
#  {'city': 'Highwood',
#   'race_w': 4377,
#   'race_aa': 243,
#   'eth_hisp': 2570,
#   'median_income': 57563.0,
#   'vio_crime': 4,
#   'prop_crime': 33,
#   'lat': 42.1997468,
#   'long': -87.8092335},
#  {'city': 'Plymouth',
#   'race_w': 1024,
#   'race_aa': 9,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.2917112,
#   'long': -90.919023},
#  {'city': 'Davis Junction',
#   'race_w': 3045,
#   'race_aa': 72,
#   'eth_hisp': 331,
#   'median_income': 68654.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 42.1016919,
#   'long': -89.0931574},
#  {'city': 'Leland',
#   'race_w': 1737,
#   'race_aa': 0,
#   'eth_hisp': 176,
#   'median_income': 66971.0,
#   'vio_crime': 0,
#   'prop_crime': 2,
#   'lat': 41.6125306,
#   'long': -88.7995237},
#  {'city': 'Franklin',
#   'race_w': 1361,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 39.6203259,
#   'long': -90.0440001},
#  {'city': 'Mill Shoals',
#   'race_w': 328,
#   'race_aa': 0,
#   'eth_hisp': 1,
#   'median_income': nan,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 38.2486586,
#   'long': -88.3467125},
#  {'city': 'Cropsey',
#   'race_w': 194,
#   'race_aa': 0,
#   'eth_hisp': 0,
#   'median_income': 112578.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.6092009,
#   'long': -88.4786678},
#  {'city': 'Roseville',
#   'race_w': 1460,
#   'race_aa': 20,
#   'eth_hisp': 30,
#   'median_income': 44883.0,
#   'vio_crime': 0,
#   'prop_crime': 0,
#   'lat': 40.7322617,
#   'long': -90.6645784},
#  {'city': 'Wheeling',
#   'race_w': 24056,
#   'race_aa': 1499,
#   'eth_hisp': 11769,
#   'median_income': 66243.0,
#   'vio_crime': 27,
#   'prop_crime': 322,
#   'lat': 42.1391928,
#   'long': -87.9289591},
#  ...]
